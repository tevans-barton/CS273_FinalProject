# %%
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tourney = pd.read_csv('data/raw/MNCAATourneyCompactResults.csv')
reg_season = pd.read_csv('data/raw/MRegularSeasonDetailedResults.csv')
teams = pd.read_csv('data/raw/MTeams.csv')

# %%
wins = reg_season[['Season', 'WTeamID', 'WScore', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF']]
losses = reg_season[['Season', 'LTeamID', 'LScore', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']]

# %%
wins.columns = ['Season', 'TeamID', 'Score', 'FGM', 'FGA', 'FGM3', 'FGA3', 'FTM', 'FTA', 'OR', 'DR', 'Ast', 'TO', 'Stl', 'Blk', 'PF']
losses.columns = ['Season', 'TeamID', 'Score', 'FGM', 'FGA', 'FGM3', 'FGA3', 'FTM', 'FTA', 'OR', 'DR', 'Ast', 'TO', 'Stl', 'Blk', 'PF']

# %%
w_grouped = wins.groupby(['Season', 'TeamID']).aggregate(['sum', 'count'])
l_grouped = losses.groupby(['Season', 'TeamID']).aggregate(['sum', 'count'])

# %%
w_grouped.columns = ['_'.join(map(str, col)) for col in w_grouped.columns.values]
l_grouped.columns = ['_'.join(map(str, col)) for col in l_grouped.columns.values]

# %%
w_grouped = w_grouped[['Score_sum', 'FGM_sum', 'FGA_sum', 'FGM3_sum', 'FGA3_sum', 'FTM_sum', 'FTA_sum', 'OR_sum','DR_sum', 'Ast_sum', 'TO_sum', 'Stl_sum', 'Blk_sum', 'PF_sum', 'PF_count']]
w_grouped.columns = ['Points', 'FGM', 'FGA', 'FGM3', 'FGA3','FTM', 'FTA', 'OR','DR', 'Ast', 'TO','Stl', 'Blk', 'PF', 'Games']
l_grouped = l_grouped[['Score_sum', 'FGM_sum', 'FGA_sum', 'FGM3_sum', 'FGA3_sum', 'FTM_sum', 'FTA_sum', 'OR_sum','DR_sum', 'Ast_sum', 'TO_sum', 'Stl_sum', 'Blk_sum', 'PF_sum', 'PF_count']]
l_grouped.columns = ['Points', 'FGM', 'FGA', 'FGM3', 'FGA3','FTM', 'FTA', 'OR','DR', 'Ast', 'TO','Stl', 'Blk', 'PF', 'Games']

# %%
reg_season_stats = w_grouped.add(l_grouped, fill_value = 0)

# %%
reg_season_stats = reg_season_stats.reset_index(drop = False)

# %%
reg_season_stats = reg_season_stats.dropna().reset_index(drop = True)

# %%
for c in ['Points', 'FGM', 'FGA', 'FGM3', 'FGA3', 'FTM', 'FTA', 'OR', 'DR', 'Ast', 'TO', 'Stl', 'Blk', 'PF']:
    reg_season_stats[c] = reg_season_stats[c] / reg_season_stats['Games']

# %%
reg_season_stats
# Out:
#       Season  TeamID     Points        FGM        FGA      FGM3       FGA3  \
# 0       2003    1102  57.250000  19.142857  39.785714  7.821429  20.821429
# 1       2003    1103  78.777778  27.148148  55.851852  5.444444  16.074074
# 2       2003    1104  69.285714  24.035714  57.178571  6.357143  19.857143
# 3       2003    1105  71.769231  24.384615  61.615385  7.576923  20.769231
# 4       2003    1106  63.607143  23.428571  55.285714  6.107143  17.642857
# ...      ...     ...        ...        ...        ...       ...        ...
# 8330    2026    1477  67.066667  23.433333  55.800000  8.066667  25.800000
# 8331    2026    1478  72.322581  24.709677  54.129032  7.580645  22.096774
# 8332    2026    1479  68.250000  25.750000  57.906250  5.781250  18.000000
# 8333    2026    1480  75.333333  27.766667  62.900000  6.866667  20.733333
# 8334    2026    1481  61.464286  21.928571  51.357143  6.178571  20.464286
#
#             FTM        FTA         OR         DR        Ast         TO  \
# 0     11.142857  17.107143   4.178571  16.821429  13.000000  11.428571
# 1     19.037037  25.851852   9.777778  19.925926  15.222222  12.629630
# 2     14.857143  20.928571  13.571429  23.928571  12.107143  13.285714
# 3     15.423077  21.846154  13.500000  23.115385  14.538462  18.653846
# 4     10.642857  16.464286  12.285714  23.857143  11.678571  17.035714
# ...         ...        ...        ...        ...        ...        ...
# 8330  12.133333  17.866667   7.400000  21.766667  14.633333  12.566667
# 8331  15.322581  21.354839   7.000000  24.903226  13.967742  12.451613
# 8332  10.968750  14.812500   7.437500  21.437500  13.968750   8.625000
# 8333  12.933333  18.366667  10.033333  23.100000  12.300000  10.700000
# 8334  11.428571  16.285714   5.785714  21.107143  10.892857  10.357143
#
#            Stl       Blk         PF  Games
# 0     5.964286  1.785714  18.750000   28.0
# 1     7.259259  2.333333  19.851852   27.0
# 2     6.607143  3.785714  18.035714   28.0
# 3     9.307692  2.076923  20.230769   26.0
# 4     8.357143  3.142857  18.178571   28.0
# ...        ...       ...        ...    ...
# 8330  6.733333  3.133333  16.900000   30.0
# 8331  5.483871  3.290323  17.483871   31.0
# 8332  6.968750  3.843750  18.375000   32.0
# 8333  6.366667  4.666667  17.233333   30.0
# 8334  6.035714  2.035714  14.142857   28.0
#
# [8335 rows x 17 columns]

# %%
round1_tourney = tourney[tourney['DayNum'].isin([136,137])].reset_index(drop = True)

# %%
tourney_winners = round1_tourney[['Season', 'WTeamID']].merge(reg_season_stats, left_on = ['Season', 'WTeamID'], right_on = ['Season', 'TeamID'], how = 'inner')

# %%
tourney_winners['Target'] = 1

# %%
tourney_losers = round1_tourney[['Season', 'LTeamID']].merge(reg_season_stats, left_on = ['Season', 'LTeamID'], right_on = ['Season', 'TeamID'], how = 'inner')

# %%
tourney_losers['Target'] = 0

# %%
tourney_winners = tourney_winners.drop('WTeamID', axis = 1)
tourney_losers = tourney_losers.drop('LTeamID', axis = 1)

# %%
data = pd.concat([tourney_winners, tourney_losers])

# %%
data = data.reset_index(drop = True)

# %%
teams
# Out:
#      TeamID        TeamName  FirstD1Season  LastD1Season
# 0      1101     Abilene Chr           2014          2026
# 1      1102       Air Force           1985          2026
# 2      1103           Akron           1985          2026
# 3      1104         Alabama           1985          2026
# 4      1105     Alabama A&M           2000          2026
# ..      ...             ...            ...           ...
# 376    1477  East Texas A&M           2023          2026
# 377    1478        Le Moyne           2024          2026
# 378    1479      Mercyhurst           2025          2026
# 379    1480    West Georgia           2025          2026
# 380    1481       New Haven           2026          2026
#
# [381 rows x 4 columns]

# %%
data['Team'] = data['TeamID'].map(teams.set_index('TeamID')['TeamName'].to_dict())

# %%
data.columns
# Out:
# Index(['Season', 'TeamID', 'Points', 'FGM', 'FGA', 'FGM3', 'FGA3', 'FTM',
#        'FTA', 'OR', 'DR', 'Ast', 'TO', 'Stl', 'Blk', 'PF', 'Games', 'Target',
#        'Team'],
#       dtype='str')

# %%
data = data[['Team', 'TeamID', 'Season', 'Points', 'FGM', 'FGA', 'FGM3', 'FGA3', 'FTM','FTA', 'OR', 'DR', 'Ast', 'TO', 'Stl', 'Blk', 'PF', 'Games', 'Target']]

# %%
data
# Out:
#                 Team  TeamID  Season     Points        FGM        FGA  \
# 0            Arizona    1112    2003  85.214286  30.321429  65.714286
# 1         Arizona St    1113    2003  75.965517  27.206897  56.896552
# 2         C Michigan    1141    2003  79.344828  26.620690  52.689655
# 3         California    1143    2003  74.482759  27.344828  58.724138
# 4        Connecticut    1163    2003  80.033333  29.533333  62.200000
# ...              ...     ...     ...        ...        ...        ...
# 1377          Bryant    1136    2025  80.343750  29.312500  64.875000
# 1378  North Carolina    1314    2025  80.800000  28.714286  60.285714
# 1379       Marquette    1266    2025  76.878788  27.848485  62.545455
# 1380         Liberty    1251    2025  74.354839  26.580645  54.225806
# 1381      Vanderbilt    1435    2025  79.625000  27.906250  61.843750
#
#            FGM3       FGA3        FTM        FTA         OR         DR  \
# 0      7.035714  20.071429  17.535714  25.000000  15.178571  27.642857
# 1      4.000000  12.586207  17.551724  26.206897  13.689655  23.310345
# 2      6.827586  17.931034  19.275862  25.172414  10.586207  23.275862
# 3      6.413793  17.034483  13.379310  19.517241  11.241379  24.379310
# 4      6.066667  15.700000  14.900000  22.100000  14.766667  27.900000
# ...         ...        ...        ...        ...        ...        ...
# 1377   7.531250  22.562500  14.187500  19.750000  11.750000  25.843750
